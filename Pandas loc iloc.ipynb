# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Coding\ML\data\us-500.csv', index_col = 'last_name')
data.drop('web', axis = 1, inplace = True)
data.head()
# Out:
#           first_name            company_name               address  \
# last_name
# Butt           James       Benton, John B Jr    6649 N Blue Gum St
# Darakjy    Josephine   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# Venere           Art     Chemel, James L Cpa  8 W Cerritos Ave #54
# Paprocki       Lenna  Feltz Printing Service           639 Main St
# Foller       Donette     Printing Dimensions          34 Center St
#
#                   city      county state    zip        phone1        phone2  \
# last_name
# Butt       New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# Darakjy       Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# Venere      Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# Paprocki     Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# Foller        Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                                    email
# last_name
# ...

# %%
data.iloc[0]
# Out:
# first_name                   James
# company_name     Benton, John B Jr
# address         6649 N Blue Gum St
# city                   New Orleans
# county                     Orleans
# state                           LA
# zip                          70116
# phone1                504-621-8927
# phone2                504-845-1427
# email              jbutt@gmail.com
# Name: Butt, dtype: object

# %%
data.iloc[[0, 1, 2]]
# Out:
#           first_name           company_name               address  \
# last_name
# Butt           James      Benton, John B Jr    6649 N Blue Gum St
# Darakjy    Josephine  Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# Venere           Art    Chemel, James L Cpa  8 W Cerritos Ave #54
#
#                   city      county state    zip        phone1        phone2  \
# last_name
# Butt       New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# Darakjy       Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# Venere      Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
#
#                                    email
# last_name
# Butt                     jbutt@gmail.com
# Darakjy    josephine_darakjy@darakjy.org
# Venere                    art@venere.org

# %%
data.iloc[0:5]
# Out:
#           first_name            company_name               address  \
# last_name
# Butt           James       Benton, John B Jr    6649 N Blue Gum St
# Darakjy    Josephine   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# Venere           Art     Chemel, James L Cpa  8 W Cerritos Ave #54
# Paprocki       Lenna  Feltz Printing Service           639 Main St
# Foller       Donette     Printing Dimensions          34 Center St
#
#                   city      county state    zip        phone1        phone2  \
# last_name
# Butt       New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# Darakjy       Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# Venere      Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# Paprocki     Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# Foller        Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                                    email
# last_name
# ...

# %%
data.iloc[2:11]
# Out:
#           first_name               company_name                address  \
# last_name
# Venere           Art        Chemel, James L Cpa   8 W Cerritos Ave #54
# Paprocki       Lenna     Feltz Printing Service            639 Main St
# Foller       Donette        Printing Dimensions           34 Center St
# Morasca       Simona        Chapman, Ross E Esq           3 Mcauley Dr
# Tollner       Mitsue         Morlong Associates              7 Eads St
# Dilliard       Leota           Commercial Press       7 W Jackson Blvd
# Wieser          Sage  Truhlar And Truhlar Attys       5 Boston Ave #88
# Marrier         Kris    King, Christopher A Esq  228 Runamuck Pl #2808
# Amigon         Minna          Dorl, James J Esq       2371 Jerrold Ave
#
#                   city          county state    zip        phone1  \
# last_name
# Venere      Bridgeport      Gloucester    NJ   8014  856-636-8749
# Paprocki     Anchorage       Anchorage    AK  99501  907-385-4412
# ...

# %%
data.iloc[100:]
# Out:
#           first_name                    company_name               address  \
# last_name
# Buemi         Alease         Porto Cayo At Hawks Cay     4 Webbs Chapel Rd
# Cronauer      Louisa  Pacific Grove Museum Ntrl Hist  524 Louisiana Ave Nw
# Cetta        Angella              Bender & Hatley Pc  185 Blackstone Bldge
# Goldammer      Cyndy             Di Cristina J & Son       170 Wyoming Ave
# Cork           Rosio                   Green Goddess           4 10th St W
# ...              ...                             ...                   ...
# Gillaspie    Brittni                     Inner Label            67 Rv Cent
# Kampa        Raylene                      Hermar Inc        2 Sw Nyberg Rd
# Bookamer         Flo    Simonton Howe & Schneider Pc       89992 E 15th St
# Biddy           Jani   Warehouse Office & Paper Prod      61556 W 20th Ave
# Motley      Chauncey      Affiliated With Travelodge        63 E Aurora Dr
#
# ...

# %%
data.iloc[-1]
# Out:
# first_name                        Chauncey
# company_name    Affiliated With Travelodge
# address                     63 E Aurora Dr
# city                               Orlando
# county                              Orange
# state                                   FL
# zip                                  32804
# phone1                        407-413-4842
# phone2                        407-557-8857
# email              chauncey_motley@aol.com
# Name: Motley, dtype: object

# %%
data.iloc[-5:]
# Out:
#           first_name                   company_name           address  \
# last_name
# Gillaspie    Brittni                    Inner Label        67 Rv Cent
# Kampa        Raylene                     Hermar Inc    2 Sw Nyberg Rd
# Bookamer         Flo   Simonton Howe & Schneider Pc   89992 E 15th St
# Biddy           Jani  Warehouse Office & Paper Prod  61556 W 20th Ave
# Motley      Chauncey     Affiliated With Travelodge    63 E Aurora Dr
#
#                city     county state    zip        phone1        phone2  \
# last_name
# Gillaspie     Boise        Ada    ID  83709  208-709-1235  208-206-9848
# Kampa       Elkhart    Elkhart    IN  46514  574-499-1454  574-330-1884
# Bookamer   Alliance  Box Butte    NE  69301  308-726-2182  308-250-6987
# Biddy       Seattle       King    WA  98104  206-711-6498  206-395-6284
# Motley      Orlando     Orange    FL  32804  407-413-4842  407-557-8857
#
#                               email
# last_name
# Gillaspie  bgillaspie@gillaspie.com
# ...

# %%
data.iloc[:, 0]
# Out:
# last_name
# Butt             James
# Darakjy      Josephine
# Venere             Art
# Paprocki         Lenna
# Foller         Donette
#                ...
# Gillaspie      Brittni
# Kampa          Raylene
# Bookamer           Flo
# Biddy             Jani
# Motley        Chauncey
# Name: first_name, Length: 500, dtype: object

# %%
data.iloc[[0]]
# Out:
#           first_name       company_name             address         city  \
# last_name
# Butt           James  Benton, John B Jr  6649 N Blue Gum St  New Orleans
#
#             county state    zip        phone1        phone2            email
# last_name
# Butt       Orleans    LA  70116  504-621-8927  504-845-1427  jbutt@gmail.com

# %%
data.loc['Biddy', 'city']
# Out:
# 'Seattle'

# %%
data.reset_index(inplace = True)
data.set_index('first_name', inplace = True)
data.drop('index', axis = 1, inplace = True)

# %%
data.loc['Lenna']
# Out:
#            last_name            company_name      address       city  \
# first_name
# Lenna       Paprocki  Feltz Printing Service  639 Main St  Anchorage
# Lenna       Newville     Brooks, Morris J Jr  987 Main St    Raleigh
#
#                county state    zip        phone1        phone2  \
# first_name
# Lenna       Anchorage    AK  99501  907-385-4412  907-921-2010
# Lenna            Wake    NC  27601  919-623-2524  919-254-5987
#
#                              email
# first_name
# Lenna        lpaprocki@hotmail.com
# Lenna       lnewville@newville.com

# %%
my_clients = data.loc[data.loc[:, 'state'] == 'OH']
my_clients.head()
# Out:
#            last_name             company_name                 address  \
# first_name
# Donette       Foller      Printing Dimensions            34 Center St
# Simona       Morasca      Chapman, Ross E Esq            3 Mcauley Dr
# Graciela        Ruta  Buckley Miller & Wright   98 Connecticut Ave Nw
# Ammie         Corrio       Moskowitz, Barry S      74874 Atlantic Ave
# Tamar       Hoogland      A K Construction Co  2737 Pistorio Rd #9230
#
#                      city    county state    zip        phone1        phone2  \
# first_name
# Donette          Hamilton    Butler    OH  45011  513-570-1893  513-549-4561
# Simona            Ashland   Ashland    OH  44805  419-503-2484  419-800-6759
# Graciela    Chagrin Falls    Geauga    OH  44023  440-780-8425  440-579-7763
# Ammie            Columbus  Franklin    OH  43215  614-801-9788  614-648-3265
# Tamar              London   Madison    OH  43140  740-343-8575  740-526-5410
#
#                              email
# first_name
# ...

# %%
my_clients.shape[0]
# Out:
# 22

# %%
data.loc[:, 'state'] == 'OH'
# Out:
# first_name
# James        False
# Josephine    False
# Art          False
# Lenna        False
# Donette       True
#              ...
# Brittni      False
# Raylene      False
# Flo          False
# Jani         False
# Chauncey     False
# Name: state, Length: 500, dtype: bool

# %%
data.loc[data.loc[:, 'email'].str.endswith('gmail.com')].head()
# Out:
#            last_name             company_name                address  \
# first_name
# James           Butt        Benton, John B Jr     6649 N Blue Gum St
# Kris         Marrier  King, Christopher A Esq  228 Runamuck Pl #2808
# Abel         Maclead      Rangoni Of Florence     37275 St  Rt 17m M
# Cammy        Albares   Rousseaux, Michael Esq       56 E Morehead St
# Alishia        Sergi  Milford Enterprises Inc  2742 Distribution Way
#
#                      city          county state    zip        phone1  \
# first_name
# James         New Orleans         Orleans    LA  70116  504-621-8927
# Kris            Baltimore  Baltimore City    MD  21224  410-655-8723
# Abel        Middle Island         Suffolk    NY  11953  631-335-3414
# Cammy              Laredo            Webb    TX  78045  956-537-6195
# Alishia          New York        New York    NY  10025  212-860-1579
#
#                   phone2               email
# first_name
# James       504-845-1427     jbutt@gmail.com
# ...

# %%
data.loc[(data.loc[:, 'state'] == 'OH') & (data.loc[:, 'city'] == 'Hamilton')]
# Out:
#            last_name         company_name       address      city  county  \
# first_name
# Donette       Foller  Printing Dimensions  34 Center St  Hamilton  Butler
#
#            state    zip        phone1        phone2                   email
# first_name
# Donette       OH  45011  513-570-1893  513-549-4561  donette.foller@cox.net

# %%
state_ohio = data.loc[:, 'state'] == 'OH'
city_Hamilton = data.loc[:, 'city'] == 'Hamilton'
data.loc[state_ohio & city_Hamilton]
# Out:
#            last_name         company_name       address      city  county  \
# first_name
# Donette       Foller  Printing Dimensions  34 Center St  Hamilton  Butler
#
#            state    zip        phone1        phone2                   email
# first_name
# Donette       OH  45011  513-570-1893  513-549-4561  donette.foller@cox.net
